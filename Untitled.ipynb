# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt # plotting
import numpy as np # linear algebra
import os # accessing directory structure
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
from autoviz.AutoViz_Class import AutoViz_Class

# %%
data = pd.read_csv("states_all.csv")
data
# Out:
#              PRIMARY_KEY          STATE  YEAR  ENROLL  TOTAL_REVENUE  \
# 0           1992_ALABAMA        ALABAMA  1992     NaN      2678885.0
# 1            1992_ALASKA         ALASKA  1992     NaN      1049591.0
# 2           1992_ARIZONA        ARIZONA  1992     NaN      3258079.0
# 3          1992_ARKANSAS       ARKANSAS  1992     NaN      1711959.0
# 4        1992_CALIFORNIA     CALIFORNIA  1992     NaN     26260025.0
# ...                  ...            ...   ...     ...            ...
# 1710       2019_VIRGINIA       VIRGINIA  2019     NaN            NaN
# 1711     2019_WASHINGTON     WASHINGTON  2019     NaN            NaN
# 1712  2019_WEST_VIRGINIA  WEST_VIRGINIA  2019     NaN            NaN
# 1713      2019_WISCONSIN      WISCONSIN  2019     NaN            NaN
# 1714        2019_WYOMING        WYOMING  2019     NaN            NaN
#
#       FEDERAL_REVENUE  STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  \
# ...

# %%
data.shape
# Out:
# (1715, 25)

# %%
data.isnull()
# Out:
#       PRIMARY_KEY  STATE   YEAR  ENROLL  TOTAL_REVENUE  FEDERAL_REVENUE  \
# 0           False  False  False    True          False            False
# 1           False  False  False    True          False            False
# 2           False  False  False    True          False            False
# 3           False  False  False    True          False            False
# 4           False  False  False    True          False            False
# ...           ...    ...    ...     ...            ...              ...
# 1710        False  False  False    True           True             True
# 1711        False  False  False    True           True             True
# 1712        False  False  False    True           True             True
# 1713        False  False  False    True           True             True
# 1714        False  False  False    True           True             True
#
#       STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  \
# ...

# %%
data.isnull().sum()
# Out:
# PRIMARY_KEY                        0
# STATE                              0
# YEAR                               0
# ENROLL                           491
# TOTAL_REVENUE                    440
# FEDERAL_REVENUE                  440
# STATE_REVENUE                    440
# LOCAL_REVENUE                    440
# TOTAL_EXPENDITURE                440
# INSTRUCTION_EXPENDITURE          440
# SUPPORT_SERVICES_EXPENDITURE     440
# OTHER_EXPENDITURE                491
# CAPITAL_OUTLAY_EXPENDITURE       440
# GRADES_PK_G                      173
# GRADES_KG_G                       83
# GRADES_4_G                        83
# GRADES_8_G                        83
# GRADES_12_G                       83
# GRADES_1_8_G                     695
# GRADES_9_12_G                    644
# GRADES_ALL_G                      83
# AVG_MATH_4_SCORE                1150
# AVG_MATH_8_SCORE                1113
# AVG_READING_4_SCORE             1065
# AVG_READING_8_SCORE             1153
# dtype: int64

# %%
data_1 = data.fillna(value=data['ENROLL'].min())
data_1
# Out:
#              PRIMARY_KEY          STATE  YEAR   ENROLL  TOTAL_REVENUE  \
# 0           1992_ALABAMA        ALABAMA  1992  43866.0      2678885.0
# 1            1992_ALASKA         ALASKA  1992  43866.0      1049591.0
# 2           1992_ARIZONA        ARIZONA  1992  43866.0      3258079.0
# 3          1992_ARKANSAS       ARKANSAS  1992  43866.0      1711959.0
# 4        1992_CALIFORNIA     CALIFORNIA  1992  43866.0     26260025.0
# ...                  ...            ...   ...      ...            ...
# 1710       2019_VIRGINIA       VIRGINIA  2019  43866.0        43866.0
# 1711     2019_WASHINGTON     WASHINGTON  2019  43866.0        43866.0
# 1712  2019_WEST_VIRGINIA  WEST_VIRGINIA  2019  43866.0        43866.0
# 1713      2019_WISCONSIN      WISCONSIN  2019  43866.0        43866.0
# 1714        2019_WYOMING        WYOMING  2019  43866.0        43866.0
#
#       FEDERAL_REVENUE  STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  \
# ...

# %%
data_2 = data_1.fillna(method='pad')
data_2
# Out:
#              PRIMARY_KEY          STATE  YEAR   ENROLL  TOTAL_REVENUE  \
# 0           1992_ALABAMA        ALABAMA  1992  43866.0      2678885.0
# 1            1992_ALASKA         ALASKA  1992  43866.0      1049591.0
# 2           1992_ARIZONA        ARIZONA  1992  43866.0      3258079.0
# 3          1992_ARKANSAS       ARKANSAS  1992  43866.0      1711959.0
# 4        1992_CALIFORNIA     CALIFORNIA  1992  43866.0     26260025.0
# ...                  ...            ...   ...      ...            ...
# 1710       2019_VIRGINIA       VIRGINIA  2019  43866.0        43866.0
# 1711     2019_WASHINGTON     WASHINGTON  2019  43866.0        43866.0
# 1712  2019_WEST_VIRGINIA  WEST_VIRGINIA  2019  43866.0        43866.0
# 1713      2019_WISCONSIN      WISCONSIN  2019  43866.0        43866.0
# 1714        2019_WYOMING        WYOMING  2019  43866.0        43866.0
#
#       FEDERAL_REVENUE  STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  \
# ...

# %%
data_3 = data_2.fillna(value='0')
data_3
# Out:
#              PRIMARY_KEY          STATE  YEAR   ENROLL  TOTAL_REVENUE  \
# 0           1992_ALABAMA        ALABAMA  1992  43866.0      2678885.0
# 1            1992_ALASKA         ALASKA  1992  43866.0      1049591.0
# 2           1992_ARIZONA        ARIZONA  1992  43866.0      3258079.0
# 3          1992_ARKANSAS       ARKANSAS  1992  43866.0      1711959.0
# 4        1992_CALIFORNIA     CALIFORNIA  1992  43866.0     26260025.0
# ...                  ...            ...   ...      ...            ...
# 1710       2019_VIRGINIA       VIRGINIA  2019  43866.0        43866.0
# 1711     2019_WASHINGTON     WASHINGTON  2019  43866.0        43866.0
# 1712  2019_WEST_VIRGINIA  WEST_VIRGINIA  2019  43866.0        43866.0
# 1713      2019_WISCONSIN      WISCONSIN  2019  43866.0        43866.0
# 1714        2019_WYOMING        WYOMING  2019  43866.0        43866.0
#
#       FEDERAL_REVENUE  STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  \
# ...

# %%
data_4 = data.fillna({'ENROLL':'77'})
data_4
# Out:
#              PRIMARY_KEY          STATE  YEAR ENROLL  TOTAL_REVENUE  \
# 0           1992_ALABAMA        ALABAMA  1992     77      2678885.0
# 1            1992_ALASKA         ALASKA  1992     77      1049591.0
# 2           1992_ARIZONA        ARIZONA  1992     77      3258079.0
# 3          1992_ARKANSAS       ARKANSAS  1992     77      1711959.0
# 4        1992_CALIFORNIA     CALIFORNIA  1992     77     26260025.0
# ...                  ...            ...   ...    ...            ...
# 1710       2019_VIRGINIA       VIRGINIA  2019     77            NaN
# 1711     2019_WASHINGTON     WASHINGTON  2019     77            NaN
# 1712  2019_WEST_VIRGINIA  WEST_VIRGINIA  2019     77            NaN
# 1713      2019_WISCONSIN      WISCONSIN  2019     77            NaN
# 1714        2019_WYOMING        WYOMING  2019     77            NaN
#
#       FEDERAL_REVENUE  STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  \
# 0            304177.0      1659028.0       715680.0          2653798.0
# ...

# %%
data_5 = data.fillna(value=data['TOTAL_REVENUE'].min())
data_5
# Out:
#              PRIMARY_KEY          STATE  YEAR    ENROLL  TOTAL_REVENUE  \
# 0           1992_ALABAMA        ALABAMA  1992  465650.0      2678885.0
# 1            1992_ALASKA         ALASKA  1992  465650.0      1049591.0
# 2           1992_ARIZONA        ARIZONA  1992  465650.0      3258079.0
# 3          1992_ARKANSAS       ARKANSAS  1992  465650.0      1711959.0
# 4        1992_CALIFORNIA     CALIFORNIA  1992  465650.0     26260025.0
# ...                  ...            ...   ...       ...            ...
# 1710       2019_VIRGINIA       VIRGINIA  2019  465650.0       465650.0
# 1711     2019_WASHINGTON     WASHINGTON  2019  465650.0       465650.0
# 1712  2019_WEST_VIRGINIA  WEST_VIRGINIA  2019  465650.0       465650.0
# 1713      2019_WISCONSIN      WISCONSIN  2019  465650.0       465650.0
# 1714        2019_WYOMING        WYOMING  2019  465650.0       465650.0
#
#       FEDERAL_REVENUE  STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  \
# ...

# %%
data_5.isnull().sum()
# Out:
# PRIMARY_KEY                     0
# STATE                           0
# YEAR                            0
# ENROLL                          0
# TOTAL_REVENUE                   0
# FEDERAL_REVENUE                 0
# STATE_REVENUE                   0
# LOCAL_REVENUE                   0
# TOTAL_EXPENDITURE               0
# INSTRUCTION_EXPENDITURE         0
# SUPPORT_SERVICES_EXPENDITURE    0
# OTHER_EXPENDITURE               0
# CAPITAL_OUTLAY_EXPENDITURE      0
# GRADES_PK_G                     0
# GRADES_KG_G                     0
# GRADES_4_G                      0
# GRADES_8_G                      0
# GRADES_12_G                     0
# GRADES_1_8_G                    0
# GRADES_9_12_G                   0
# GRADES_ALL_G                    0
# AVG_MATH_4_SCORE                0
# AVG_MATH_8_SCORE                0
# AVG_READING_4_SCORE             0
# AVG_READING_8_SCORE             0
# dtype: int64

# %%
data_5.boxplot(column="ENROLL")
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(8,6))
plt.title('Before Scaling')
sns.kdeplot(data['ENROLL'])
sns.kdeplot(data['TOTAL_REVENUE'])
sns.kdeplot(data['FEDERAL_REVENUE'])
sns.kdeplot(data['STATE_REVENUE'])

plt.show()

data_5
# Out:
#              PRIMARY_KEY          STATE  YEAR    ENROLL  TOTAL_REVENUE  \
# 0           1992_ALABAMA        ALABAMA  1992  465650.0      2678885.0
# 1            1992_ALASKA         ALASKA  1992  465650.0      1049591.0
# 2           1992_ARIZONA        ARIZONA  1992  465650.0      3258079.0
# 3          1992_ARKANSAS       ARKANSAS  1992  465650.0      1711959.0
# 4        1992_CALIFORNIA     CALIFORNIA  1992  465650.0     26260025.0
# ...                  ...            ...   ...       ...            ...
# 1710       2019_VIRGINIA       VIRGINIA  2019  465650.0       465650.0
# 1711     2019_WASHINGTON     WASHINGTON  2019  465650.0       465650.0
# 1712  2019_WEST_VIRGINIA  WEST_VIRGINIA  2019  465650.0       465650.0
# 1713      2019_WISCONSIN      WISCONSIN  2019  465650.0       465650.0
# 1714        2019_WYOMING        WYOMING  2019  465650.0       465650.0
#
#       FEDERAL_REVENUE  STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  \
# ...

# %%
# !pip install autoviz

# %%
from autoviz.AutoViz_Class import AutoViz_Class

AV = AutoViz_Class()

# %%
filename = "states_all.csv"
sep = ","
dft = AV.AutoViz(
    filename,
    sep=",",
    depVar="",
    dfte=None,
    header=0,
    verbose=0,
    lowess=False,
    chart_format="svg",
    max_rows_analyzed=150000,
    max_cols_analyzed=30,
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-11e0ec241303> in <module>
#       1 filename = "states_all.csv"
#       2 sep = ","
# ----> 3 dft = AV.AutoViz(
#       4     filename,
#       5     sep=",",
#
# NameError: name 'AV' is not defined
